# %% [markdown]
# # Day 3: Tissue organisation, communication, interpretation
#
# This session is **self-contained** and nothing here depends on days 1 to 2.
#
# **You will learn to**
# - read tissue organisation with neighbourhood enrichment and co-occurrence;
# - define niches from neighbourhood composition;
# - score ligand-receptor interactions;
# - rank spatially variable genes and interpret a finding end to end.

# %% [markdown]
# ### Setup (run first)
#
# On the course servers this does nothing, since the packages are pre-installed. On Google Colab or a fresh laptop it installs what is missing. Data downloads automatically the first time it is needed, except the Xenium bundle on Day 2 (see the README).

# %%
import importlib, subprocess, sys
_req = [('scanpy','scanpy'), ('squidpy','squidpy'), ('leidenalg','leidenalg'),
        ('igraph','igraph'), ('pyclustree','pyclustree'),
        ('scikit-image','skimage'), ('imageio','imageio')]
_missing = [pip for pip, mod in _req if importlib.util.find_spec(mod) is None]
if _missing:
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', *_missing], check=False)
print('environment ready')
# Out:
# environment ready

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import scanpy as sc
import squidpy as sq
import matplotlib.pyplot as plt

sc.settings.verbosity = 1
plt.rcParams.update({
    "figure.facecolor": "white",
    "axes.titleweight": "normal",
    "axes.labelweight": "normal",
    "axes.titlesize": 11,
    "font.weight": "normal",
    "figure.dpi": 110,
})

def _data_dir():
    env = os.environ.get("SPATIAL_COURSE_DATA")
    if env:
        return Path(env)
    shared = Path("/home/shared/spatial_course_data")
    if shared.exists():
        return shared
    local = Path.home() / "spatial_course_data"
    local.mkdir(parents=True, exist_ok=True)
    return local

DATA_DIR = _data_dir()
RESULTS = Path("results")
RESULTS.mkdir(exist_ok=True)

def load_visium():
    p = DATA_DIR / "visium_lymph_node.h5ad"
    if p.exists():
        adata = sc.read_h5ad(p)
    else:
        adata = sc.datasets.visium_sge(sample_id="V1_Human_Lymph_Node")
        try:
            adata.write(p)
        except Exception:
            pass
    adata.var_names_make_unique()
    return adata

def load_seqfish():
    p = DATA_DIR / "seqfish_embryo.h5ad"
    if p.exists():
        return sc.read_h5ad(p)
    adata = sq.datasets.seqfish()
    try:
        adata.write(p)
    except Exception:
        pass
    return adata

def xenium_dir():
    d = DATA_DIR / "xenium_kidney"
    if (d / "cell_feature_matrix.h5").exists():
        return d
    raise FileNotFoundError(
        f"Xenium bundle not found in {d}. See the README (Data): download the 10x "
        "Xenium Output Bundle once and unzip it there, or run scripts/prefetch_data.py."
    )

print("data dir:", DATA_DIR)
# Out:
# data dir: /home/robin/spatial_course_data

# %% [markdown]
# ## 1. Load the annotated dataset
#
# Cell types are already provided, so we go straight to organisation.

# %%
adata = load_seqfish()
ct_col = 'celltype_mapped_refined'
if ct_col not in adata.obs:
    ct_col = next(c for c in adata.obs.columns if 'celltype' in c.lower() or 'cell_type' in c.lower())
print('cell type column:', ct_col)
adata
# Out:
# cell type column: celltype_mapped_refined
# AnnData object with n_obs × n_vars = 19416 × 351
#     obs: 'Area', 'celltype_mapped_refined'
#     uns: 'celltype_mapped_refined_colors'
#     obsm: 'X_umap', 'spatial'

# %%
## Normalize
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
sq.pl.spatial_scatter(adata, color=ct_col, shape=None, size=2, figsize=(10,5))
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# /opt/conda/envs/spatial-course/lib/python3.11/site-packages/squidpy/pl/_spatial_utils.py:982: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %% [markdown]
# ### A closer look (spatial visualization)
#
# Before any statistics, look at the section a few ways: spotlight a couple of cell types with `groups=` to see how they are laid out, and crop to a coordinate box to read local architecture. The same categorical-vs-continuous and `size`/`alpha` from Days 1-2 apply here.

# %%
top_types = adata.obs[ct_col].value_counts().index[:3].tolist()
sq.pl.spatial_scatter(adata, color=ct_col, groups=top_types, shape=None, size=2)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# /opt/conda/envs/spatial-course/lib/python3.11/site-packages/squidpy/pl/_spatial_utils.py:982: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %%
xy = adata.obsm['spatial']
sel = ((xy[:, 0] > np.quantile(xy[:, 0], 0.4)) & (xy[:, 0] < np.quantile(xy[:, 0], 0.6)) &
       (xy[:, 1] > np.quantile(xy[:, 1], 0.4)) & (xy[:, 1] < np.quantile(xy[:, 1], 0.6)))
sub = adata[sel].copy()
print(sub.n_obs, 'cells in crop')
sq.pl.spatial_scatter(sub, color=ct_col, shape=None, size=100, figsize=(10, 5))
# Out:
# 470 cells in crop
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# /opt/conda/envs/spatial-course/lib/python3.11/site-packages/squidpy/pl/_spatial_utils.py:982: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %% [markdown]
# ## 2. Neighbourhood enrichment
#
# > **Method note: what the score is, and its caveats.** For each pair of cell types, count adjacent cells on the graph, then permute labels to get a null and report $z = (O-\mu_\pi)/\sigma_\pi$. Permutation preserves composition but destroys spatial arrangement, so $z>0$ means the pair is adjacent more than chance (co-location) and $z<0$ means avoidance. The score is relative to the chosen graph and the section's composition, so a difference between samples can be a composition difference. Dedicated niche tools (CellCharter, BANKSY) turn the same idea into reusable domain labels; we start from the raw enrichment.

# %%
sq.gr.spatial_neighbors(adata, coord_type='generic', delaunay=True)
sq.gr.nhood_enrichment(adata, cluster_key=ct_col)
sq.pl.nhood_enrichment(adata, cluster_key=ct_col, figsize=(7, 7))
# Out:
# INFO     Creating graph using `generic` coordinates and `None` transform and `1` libraries.
#   0%|          | 0/1000 [00:00<?, ?/s]

# %% [markdown]
# > **Reading the enrichment map.** Rows and columns are cell types, coloured by z-score. The diagonal is self-aggregation (does a type cluster together). Off the diagonal, warm means two types are neighbours more than chance (co-location), cool means avoidance. The magnitude is a permutation signal-to-noise, not a probability, and it depends on the graph and composition, so confirm a striking pair by plotting both types in space.

# %% [markdown]
# > **Exercise 1.** From the matrix, name two cell-type pairs that co-locate and two that avoid each other. For one co-locating pair, give a one-line biological guess.

# %% [markdown]
# **Solution.**

# %%
z = pd.DataFrame(adata.uns[f'{ct_col}_nhood_enrichment']['zscore'],
                 index=adata.obs[ct_col].cat.categories,
                 columns=adata.obs[ct_col].cat.categories)
pairs = z.stack().sort_values()
print('avoid:'); print(pairs.head(4))
print('co-locate:'); print(pairs.tail(4))
# Out:
# avoid:
# Gut tube                      Forebrain/Midbrain/Hindbrain   -44.647178
# Forebrain/Midbrain/Hindbrain  Gut tube                       -44.647178
#                               Spinal cord                    -44.480290
# Spinal cord                   Forebrain/Midbrain/Hindbrain   -44.480290
# dtype: float64
# co-locate:
# Gut tube                      Gut tube                        178.653645
# Presomitic mesoderm           Presomitic mesoderm             181.308851
# Cardiomyocytes                Cardiomyocytes                  192.773772
# Forebrain/Midbrain/Hindbrain  Forebrain/Midbrain/Hindbrain    202.311854
# dtype: float64

# %% [markdown]
# ## 3. Co-occurrence across distance
#
# The co-occurrence score for types $A,B$ at distance $d$ is $\dfrac{p(B \mid A, d)}{p(B)}$: above 1 means $B$ is enriched within distance $d$ of $A$. Plotting it against $d$ shows whether an association is short-range contact or broad regional co-occurrence.

# %%
sq.gr.co_occurrence(adata, cluster_key=ct_col)
focus = adata.obs[ct_col].value_counts().index[0]
sq.pl.co_occurrence(adata, cluster_key=ct_col, clusters=focus, figsize=(7,7))
print('focus:', focus)
# Out:
# focus: Forebrain/Midbrain/Hindbrain

# %% [markdown]
# > **Reading co-occurrence.** The curve is $p(B \mid A, d)/p(B)$ against distance $d$: above 1 means $B$ is enriched around $A$ at that range, 1 is no association, below 1 is depletion. A short-range peak is contact; a long plateau above 1 is regional co-occurrence; a decaying curve is a gradient away from $A$.

# %% [markdown]
# ## 4. Niches from neighbourhood composition
#
# > **Method note: the recipe, the maths, and the assumptions.** For each cell $i$, form the cell-type composition of its spatial neighbourhood, $h_i \in \mathbb{R}^T$ with $\sum_t h_{it}=1$ over the $T$ types, then cluster the $h_i$ with k-means, which minimises $\sum_k \sum_{i \in C_k} \lVert h_i - \mu_k \rVert^2$. Each cluster is a recurring multicellular niche. Assumptions: the neighbourhood composition captures the niche, and k-means prefers roughly round, equal-spread clusters in composition space, so elongated niches can be split. There is no true $k$: scan a few values and judge by interpretability (a silhouette score or the composition crosstab can guide you). Learned methods (BANKSY, CellCharter, SpaGCN, STAGATE) can capture subtler domains but add assumptions and compute. This is the *composition*-clustering route to multicellular regions; Day 2 §9 shows the complementary *feature-augmentation* route (stacking neighbour-averaged expression before clustering), two views of the same goal.

# %%
from sklearn.cluster import KMeans
def niches(adata, ct_col, k, seed=0):
    conn = adata.obsp['spatial_connectivities']
    onehot = pd.get_dummies(adata.obs[ct_col])
    comp = conn.dot(onehot.to_numpy(dtype=float))
    denom = comp.sum(1, keepdims=True); denom[denom == 0] = 1.0
    comp = comp / denom
    labels = KMeans(n_clusters=k, n_init=10, random_state=seed).fit_predict(comp)
    return pd.Categorical(labels.astype(str))
adata.obs['niche'] = niches(adata, ct_col, k=6)
sq.pl.spatial_scatter(adata, color='niche', shape=None, size=2)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# /opt/conda/envs/spatial-course/lib/python3.11/site-packages/squidpy/pl/_spatial_utils.py:982: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %%
pd.crosstab(adata.obs['niche'], adata.obs[ct_col], normalize='index').round(2)
# Out:
# celltype_mapped_refined  Allantois  Anterior somitic tissues  Cardiomyocytes  \
# niche
# 0                             0.00                      0.00            0.00
# 1                             0.00                      0.00            0.00
# 2                             0.01                      0.01            0.09
# 3                             0.00                      0.00            0.01
# 4                             0.00                      0.00            0.00
# 5                             0.02                      0.00            0.00
#
# celltype_mapped_refined  Cranial mesoderm  Definitive endoderm  Dermomyotome  \
# niche
# 0                                    0.01                 0.01          0.01
# 1                                    0.02                 0.00          0.00
# 2                                    0.05                 0.02          0.06
# 3                                    0.00                 0.00          0.00
# 4                                    0.01                 0.01          0.00
# 5                                    0.00                 0.00          0.00
#
# celltype_mapped_refined  Endothelium  Erythroid  Forebrain/Midbrain/Hindbrain  \
# niche
# 0                               0.00       0.00                          0.04
# 1                               0.04       0.00                          0.00
# 2                               0.10       0.03                          0.02
# 3                               0.02       0.01                          0.00
# 4                               0.00       0.00                          0.89
# 5                               0.03       0.00                          0.00
#
# celltype_mapped_refined  Gut tube  ...  Lateral plate mesoderm  Low quality  \
# niche                              ...
# 0                            0.01  ...                    0.00         0.11
# 1                            0.86  ...                    0.00         0.03
# 2                            0.01  ...                    0.02         0.12
# 3                            0.02  ...                    0.01         0.04
# 4                            0.00  ...                    0.00         0.06
# 5                            0.01  ...                    0.68         0.03
#
# celltype_mapped_refined  Mixed mesenchymal mesoderm  Neural crest   NMP  \
# niche
# 0                                              0.00          0.00  0.03
# 1                                              0.00          0.01  0.00
# 2                                              0.06          0.10  0.00
# 3                                              0.02          0.00  0.00
# 4                                              0.00          0.01  0.00
# 5                                              0.02          0.00  0.00
#
# celltype_mapped_refined  Presomitic mesoderm  Sclerotome  Spinal cord  \
# niche
# 0                                       0.01        0.00         0.75
# 1                                       0.00        0.00         0.00
# 2                                       0.05        0.01         0.03
# 3                                       0.00        0.00         0.01
# 4                                       0.00        0.00         0.02
# 5                                       0.00        0.00         0.01
#
# celltype_mapped_refined  Splanchnic mesoderm  Surface ectoderm
# niche
# 0                                       0.00              0.01
# 1                                       0.01              0.01
# 2                                       0.02              0.09
# 3                                       0.79              0.02
# 4                                       0.00              0.00
# 5                                       0.03              0.01
#
# [6 rows x 22 columns]

# %% [markdown]
# > **Exercise 2.** Recompute niches with k=4 and k=8 (use the `niches` helper). Compare the crosstabs. Which k gives interpretable, distinct compositions, and why did you pick it?

# %% [markdown]
# **Solution.**

# %%
for k in (4, 8):
    lab = niches(adata, ct_col, k=k)
    ct = pd.crosstab(lab, adata.obs[ct_col], normalize='index').round(2)
    print(f'k={k}'); print(ct); print()
# Out:
# k=4
# celltype_mapped_refined  Allantois  Anterior somitic tissues  Cardiomyocytes  \
# row_0
# 0                             0.01                      0.01            0.07
# 1                             0.00                      0.00            0.00
# 2                             0.00                      0.00            0.00
# 3                             0.00                      0.00            0.00
#
# celltype_mapped_refined  Cranial mesoderm  Definitive endoderm  Dermomyotome  \
# row_0
# 0                                    0.04                 0.01          0.05
# 1                                    0.01                 0.01          0.00
# 2                                    0.02                 0.00          0.00
# 3                                    0.01                 0.01          0.01
#
# celltype_mapped_refined  Endothelium  Erythroid  Forebrain/Midbrain/Hindbrain  \
# row_0
# 0                               0.08       0.03                          0.01
# 1                               0.00       0.00                          0.89
# 2                               0.04       0.00                          0.00
# 3                               0.00       0.00                          0.04
#
# celltype_mapped_refined  Gut tube  ...  Lateral plate mesoderm  Low quality  \
# row_0                              ...
# 0                            0.01  ...                    0.11         0.10
# 1                            0.00  ...                    0.00         0.06
# 2                            0.85  ...                    0.00         0.02
# 3                            0.01  ...                    0.00         0.11
#
# celltype_mapped_refined  Mixed mesenchymal mesoderm  Neural crest   NMP  \
# row_0
# 0                                              0.05          0.08  0.00
# 1                                              0.00          0.01  0.00
# 2                                              0.00          0.01  0.00
# 3                                              0.00          0.00  0.03
#
# celltype_mapped_refined  Presomitic mesoderm  Sclerotome  Spinal cord  \
# row_0
# 0                                       0.04        0.01         0.02
# 1                                       0.00        0.00         0.02
# 2                                       0.00        0.00         0.00
# 3                                       0.01        0.00         0.75
#
# celltype_mapped_refined  Splanchnic mesoderm  Surface ectoderm
# row_0
# 0                                       0.10              0.07
# 1                                       0.00              0.00
# 2                                       0.01              0.01
# 3                                       0.00              0.01
#
# [4 rows x 22 columns]
# k=8
# celltype_mapped_refined  Allantois  Anterior somitic tissues  Cardiomyocytes  \
# row_0
# 0                             0.00                      0.00            0.01
# 1                             0.00                      0.00            0.00
# 2                             0.00                      0.00            0.00
# 3                             0.01                      0.01            0.00
# 4                             0.00                      0.01            0.00
# 5                             0.02                      0.00            0.00
# 6                             0.00                      0.00            0.87
# 7                             0.00                      0.00            0.00
#
# celltype_mapped_refined  Cranial mesoderm  Definitive endoderm  Dermomyotome  \
# row_0
# 0                                    0.00                 0.00          0.00
# 1                                    0.01                 0.01          0.01
# 2                                    0.01                 0.01          0.00
# 3                                    0.06                 0.02          0.07
# 4                                    0.02                 0.00          0.02
# 5                                    0.00                 0.00          0.00
# 6                                    0.00                 0.00          0.00
# 7                                    0.02                 0.00          0.00
#
# celltype_mapped_refined  Endothelium  Erythroid  Forebrain/Midbrain/Hindbrain  \
# row_0
# 0                               0.02       0.01                          0.00
# 1                               0.00       0.00                          0.04
# 2                               0.00       0.00                          0.90
# 3                               0.11       0.04                          0.02
# 4                               0.06       0.00                          0.02
# 5                               0.03       0.00                          0.00
# 6                               0.05       0.01                          0.00
# 7                               0.04       0.00                          0.00
#
# celltype_mapped_refined  Gut tube  ...  Lateral plate mesoderm  Low quality  \
# row_0                              ...
# 0                            0.02  ...                    0.01         0.04
# 1                            0.01  ...                    0.00         0.11
# 2                            0.00  ...                    0.00         0.06
# 3                            0.02  ...                    0.03         0.14
# 4                            0.01  ...                    0.00         0.08
# 5                            0.01  ...                    0.68         0.03
# 6                            0.00  ...                    0.00         0.01
# 7                            0.86  ...                    0.00         0.02
#
# celltype_mapped_refined  Mixed mesenchymal mesoderm  Neural crest   NMP  \
# row_0
# 0                                              0.02          0.00  0.00
# 1                                              0.00          0.00  0.03
# 2                                              0.00          0.01  0.00
# 3                                              0.07          0.02  0.00
# 4                                              0.00          0.65  0.00
# 5                                              0.02          0.00  0.00
# 6                                              0.04          0.00  0.00
# 7                                              0.00          0.01  0.00
#
# celltype_mapped_refined  Presomitic mesoderm  Sclerotome  Spinal cord  \
# row_0
# 0                                       0.00        0.00         0.01
# 1                                       0.01        0.00         0.76
# 2                                       0.00        0.00         0.02
# 3                                       0.07        0.01         0.04
# 4                                       0.00        0.00         0.01
# 5                                       0.00        0.00         0.01
# 6                                       0.00        0.00         0.00
# 7                                       0.00        0.00         0.00
#
# celltype_mapped_refined  Splanchnic mesoderm  Surface ectoderm
# row_0
# 0                                       0.80              0.02
# 1                                       0.00              0.01
# 2                                       0.00              0.00
# 3                                       0.03              0.10
# 4                                       0.00              0.07
# 5                                       0.03              0.01
# 6                                       0.01              0.00
# 7                                       0.01              0.01
#
# [8 rows x 22 columns]

# %% [markdown]
# ## 5. Cell-cell communication
#
# > **Method note: how scoring works, and what to trust.** For a ligand $L$ and receptor $R$ and cell-type groups $A,B$, the CellPhoneDB-style score is the product (or mean) of mean expression, $s = \bar{L}_A \cdot \bar{R}_B$, and significance comes from permuting the cell-type labels many times to build a null for $s$. squidpy `ligrec`, LIANA, and CellPhoneDB share this logic; NicheNet adds downstream target genes; spatial-aware methods (COMMOT, NCEM) add distance or neighbour constraints. Caveats: expression is a proxy for activity, a small panel covers few pairs, the p-value depends on the permutation scheme, and segmentation errors can move a ligand to the wrong cell. Read results as hypotheses. We run offline with a small shipped table; drop `interactions` to use a full database online.

# %%
lr = pd.read_csv(Path('data/ligand_receptor_pairs.csv'))
present = lr[lr['source'].isin(adata.var_names) & lr['target'].isin(adata.var_names)]
print(f'{len(present)} of {len(lr)} pairs in panel')
present.head()
# Out:
# 3 of 40 pairs in panel
#    source  target
# 0    Dll1  Notch1
# 12  Pdgfa  Pdgfra
# 34   Dlk1  Notch1

# %%
if len(present):
    try:
        sq.gr.ligrec(adata, cluster_key=ct_col,
                     interactions=present[['source', 'target']],
                     use_raw=False, n_perms=100, seed=0)
        print('ligrec done; results in adata.uns')
    except Exception as e:
        print('ligrec skipped:', e)
else:
    print('No shipped pairs intersect this panel; add your own or run online.')
# Out:
#   0%|          | 0/100 [00:00<?, ?permutation/s]
# ligrec done; results in adata.uns

# %%
# Visualise selected sender -> receiver groups (all 22 x 22 pairs would be unreadable)
groups = [g for g in ['Lateral plate mesoderm', 'Intermediate mesoderm', 'Presomitic mesoderm',
                      'Endothelium', 'Haematoendothelial progenitors', 'Gut tube']
          if g in adata.obs[ct_col].cat.categories]
if adata.uns.get(f'{ct_col}_ligrec') is not None:
    sq.pl.ligrec(adata, cluster_key=ct_col, source_groups=groups, target_groups=groups,
                 pvalue_threshold=0.05, remove_empty_interactions=True)
# Out:
# /opt/conda/envs/spatial-course/lib/python3.11/site-packages/squidpy/pl/_ligrec.py:248: FutureWarning: The method uns_keys is deprecated and will be removed in the future. Use uns instead of uns_keys. (e.g. `k in adata.uns` or `sorted(adata.uns)`)
#   if cluster_key not in adata.uns_keys():

# %% [markdown]
# > **Reading the ligand-receptor dotplot.** Columns are sender -> receiver cell-type pairs (grouped by sender), rows are ligand | receptor pairs. Dot colour is the mean expression of the pair across the two types, dot size is $-\log_{10}$ of the permutation p-value, and a filled dot is significant. A large, bright, filled dot is the strongest hypothesis (here DLL1 | NOTCH1 into presomitic mesoderm), but it is a candidate from co-expression in neighbours, not proof of signalling.

# %% [markdown]
# > **Exercise 3.** Pick a source and target cell type and inspect the ligrec result for that pair (means and p-values). Name one interaction that looks plausible and say what neighbour relationship would support it.

# %% [markdown]
# **Solution.**

# %%
res = adata.uns.get(f'{ct_col}_ligrec')
if res is not None:
    pvals = res['pvalues']
    print(pvals.iloc[:, :3].head(10))
else:
    print('run the ligrec cell first')
# Out:
# cluster_1     Allantois
# cluster_2     Allantois Anterior somitic tissues Cardiomyocytes
# source target
# DLL1   NOTCH1       1.0                      0.0            1.0
# PDGFA  PDGFRA       0.0                      0.0            1.0
# DLK1   NOTCH1       0.0                      0.0            0.0

# %% [markdown]
# **Answer.** Three shipped pairs intersect the seqFISH panel: Dll1–Notch1, Dlk1–Notch1, and Pdgfa–Pdgfra. Pdgfa–Pdgfra is plausible between mesoderm populations: it would be supported if the Pdgfa-source and Pdgfra-target types are enriched neighbours, and indeed lateral plate and intermediate mesoderm co-locate strongly in the enrichment matrix (§2), so a PDGF signal across that interface is a reasonable hypothesis.

# %% [markdown]
# ## 6. Spatially variable genes

# %%
sq.gr.spatial_autocorr(adata, mode='moran')
top = adata.uns['moranI'].head(4).index.tolist()
sq.pl.spatial_scatter(adata, color=top, shape=None, size=2, use_raw=False)

## Several Scanpy, squidpy plotting functions involving genes search for gene expression in raw data 
## if adata.raw exists. Therefore use_raw=False is necessary to show normalized expression. 
## Try without use_raw=False.
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %% [markdown]
# > **Reading Moran's I and Geary's C.** Both score how spatially structured a gene's expression is. Moran's I is near 1 for smooth spatial structure, near 0 for random, and negative for checkerboard patterns; Geary's C is the inverse (near 0 = structured). They run on the same graph and usually agree, so Moran's I is a fine first pass. A high score says a gene is spatially organised, not *what* it marks or that it is cell-type specific, so always plot the top hits in space (above).

# %%
sq.gr.spatial_autocorr(adata, mode='geary')
mi = adata.uns['moranI']; gc = adata.uns['gearyC']
pd.DataFrame({'moranI': mi['I'], 'gearyC': gc.loc[mi.index, 'C']}).head(8).round(3)
# Out:
#        moranI  gearyC
# Hoxb9   0.661   0.340
# Shh     0.632   0.367
# Meox1   0.630   0.371
# Foxf1   0.617   0.382
# Krt18   0.616   0.384
# Ttn     0.566   0.432
# Nr2f1   0.557   0.444
# Dlk1    0.548   0.452

# %% [markdown]
# ## 7. Ripley's K / L: clustering across scales
#
# Enrichment asks *who* is next to whom; Ripley's statistics ask, for one cell type, *how clustered* it is and *at what scale*.

# %%
sq.gr.ripley(adata, cluster_key=ct_col, mode='L')
sq.pl.ripley(adata, cluster_key=ct_col, mode='L')

# %% [markdown]
# > **A clearer read.** The plot above shows all cell types at once. Below we draw just the four most common types against the random (CSR) baseline, which is the comparison that matters: a curve above CSR means that type is clustered at that radius.

# %%
# Same statistic, fewer lines: a few types vs the random (CSR) baseline
rip = adata.uns[f'{ct_col}_ripley_L']
dfL, sims = rip['L_stat'], rip.get('sims_stat')
catcol = ct_col if ct_col in dfL.columns else [c for c in dfL.columns if c not in ('bins', 'stats')][0]
top4 = adata.obs[ct_col].value_counts().index[:4]

plt.figure(figsize=(7, 4))
for name in top4:
    sub = dfL[dfL[catcol] == name]
    plt.plot(sub['bins'], sub['stats'], label=str(name))
if sims is not None:
    plt.plot(sims['bins'], sims['stats'], color='0.5', ls='--', lw=1, label='CSR (random)')
plt.xlabel('radius'); plt.ylabel("Ripley's L")
plt.title("Ripley's L: above CSR = clustered, below = dispersed")
plt.legend(fontsize=8); plt.show()

# %% [markdown]
# > **Reading Ripley's L.** For each cell type it counts how many same-type cells fall within a radius, against a random (complete spatial randomness, CSR) baseline. Curves above CSR mean the type is clustered at that scale; below means dispersed or regular. The radius where a curve lifts off CSR reflects the size of the structures. Most embryo types here are clustered (they form organs), strongly so for brain and spinal cord.

# %% [markdown]
# ## 8. Distance-to-structure gradients
#
# Clusters and niches are discrete. Many biological signals are instead *gradients*: expression that changes smoothly with distance from a structure. We can measure that directly.

# %%
from scipy.spatial import cKDTree

target = 'Gut tube'
xy = adata.obsm['spatial']
tgt = adata.obs[ct_col].values == target
dist, _ = cKDTree(xy[tgt]).query(xy, k=1)   # distance of every cell to nearest target cell
adata.obs['dist_to_target'] = dist

X = np.asarray(adata.X.todense()) if hasattr(adata.X, 'todense') else np.asarray(adata.X)
mask = ~tgt                                  # exclude the structure itself
corr = np.nan_to_num([np.corrcoef(dist[mask], X[mask, j])[0, 1] for j in range(adata.n_vars)])
best = np.argsort(-np.abs(corr))[:3]         # genes most associated with distance

nbins = 12
bins = np.linspace(0, np.percentile(dist[mask], 98), nbins + 1)
bc = 0.5 * (bins[:-1] + bins[1:])
plt.figure(figsize=(7, 4))
for j in best:
    vals, dd = X[mask, j], dist[mask]
    means = [vals[(dd >= bins[i]) & (dd < bins[i+1])].mean() for i in range(nbins)]
    plt.plot(bc, means, 'o-', label=f'{adata.var_names[j]} (r={corr[j]:.2f})')
plt.xlabel(f"distance to nearest '{target}' cell"); plt.ylabel('mean expression')
plt.title(f"Expression gradients vs distance to '{target}'"); plt.legend(); plt.show()

# %% [markdown]
# > **Reading distance gradients.** Giving every cell its distance to a chosen structure turns location into a continuous covariate, exposing gradients that discrete clusters and niches miss. Genes whose expression rises or falls smoothly with distance trace the transition away from that structure (here, forebrain markers such as Otx2 rise away from the gut tube). It generalises to any landmark you can define: a vessel, a tumour boundary, a wound edge.

# %% [markdown]
# > **Final exercise.** Pick one finding from today (an enriched pair, a niche, a top spatial gene). Read it end to end: what does the statistic claim in plain words; is it consistent across the section or driven by one region; what could confound it (composition, segmentation, panel limits); and what analysis or experiment would test it next? Write a short paragraph and be ready to defend it.

# %% [markdown]
# **Solution.**

# %% [markdown]
# **Worked example.** *Claim:* there is a lateral-plate-mesoderm niche, a recurring neighbourhood that is about 68% lateral plate mesoderm with intermediate mesoderm (~14%) as its second type. *Consistency:* it recurs as a coherent region, and it matches the neighbourhood-enrichment result, where lateral plate and intermediate mesoderm are among the strongest co-locating pairs of distinct cell types (z about 46). *Confounds:* a 'Low quality' label is present in the data and leaks a few percent into most niches, so check it is not driving the composition; niche number and exact fractions also depend on k and the seed. *Next:* score a PDGF (Pdgfa–Pdgfra) interaction within this niche and confirm the partners are neighbours, then look for the same niche in an independent embryo section.

# %% [markdown]
# ### Where to go next
#
# The `scverse` stack (`scanpy`, `anndata`, `squidpy`, `spatialdata`) scales the same workflow from one section to a cohort. Beyond this course: multi-sample integration and reference mapping, deconvolution for spot data, and the learned niche and communication methods named in the notes.
#
# Thank you.
